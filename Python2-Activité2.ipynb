# %% [markdown]
# # <div class="alert alert-info" role="alert"> <center> Python 2 : Activité n°2
# ## <center> Energie mécanique

# %% [markdown]
# Vous disposez du fichier "balle_tennis_lancee.csv" qui provient du pointage d'une vidéo. La masse d'une balle de tennis est de 58 g.
# ![image.png](attachment:image.png)
# Vous devez écrire un programme qui :
# - lit le fichier (il est déjà dans le même dossier que votre notebook Jupiter)
# - calcule la valeur de la vitesse à chaque instant où cela est possible.

# %% [markdown]
# ![image.png](attachment:image.png)
# - calcule l'énergie cinétique, l'énergie potentielle et l'énergie mécanique à chaque instant où cela est possible.
# - trace les énergies en fonction du temps.
# - modélise l'énergie mécanique par une équation affine.
#
# Quand vous avez terminé, vous pouvez passer à une autre activité...

# %%
# Taper votre code ici...

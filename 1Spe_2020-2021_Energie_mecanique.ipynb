# %% [markdown]
# # <div class="alert alert-info" role="alert"> <center> Energie mécanique

# %% [markdown]
# On s'intéresse au mouvement d'une balle de tennis lancée dans le champ de pesanteur. A partir du pointage de la vidéo, on a calculé la vitesse de la balle à différents instants t.
# ![image.png](attachment:image.png)
# On obtient le tableau ci-dessus qui contient 22 valeurs pour la vitesse. on appelle :
# - t, les dates correspondant à chaque image ;
# - x, l'abscisse horizontale de la balle
# - y, l'ordonnée horizontale de la balle
# - v, la valeur approchée de la vitesse instantannée de la balle
#
# Dans le programme Python ci-dessous, les valeurs du tableau ont été saisies dans des listes.
# .
# **<center>Qu'est-ce qu'une liste ?**
# Une liste est une série de valeurs que le programme va reconnaitre par son numéro. La premère valeur porte le numéro 0.
# Par exemple :
# - x[0] contient la valeur 0.264
# - y[1] contient la valeur 0.702
# .
# **<center>Calcul des énergies**
#
# On a défini 3 listes, initialement vides :
#
# - Ec pour l'énergie cinétique
# - Epp pour l'énergie potentielle de pesanteur
# - Em pour l'énergie mécanique
#
# On doit calculer les 22 valeurs de chaque énergie et les représenter en fonction du temps.
# .
# **<center>Mais que fait ce programme ?**
# Exécuter le programe ci-dessous et répondez aux questions suivantes sur une copie :
# **Question 1 :** La valeur minimale de la vitesse n'est pas la bonne. Quelle correction apporter pour que le programme donne la bonne valeur ?
# **Question 2 :** Quel titre peut-on donner au graphique de la figure 1 ? Quelle correction apporter pour que le programme affiche ce titre au-dessus du graphique ?
# **Question 3 :** Les calculs des énergies sont tous faux car les lignes de programmes sont fausses. Quelles corrections apporter pour que le programme donne les bonnes valeurs ?
# **Question 4 :** Les légendes du graphique de la figure 2 sont des points d'interrrogation.  Quelles corrections apporter pour que le programme affiche la légende correcte ?
# **Question 5 :** Quel titre peut-on donner au graphique de la figure 2 ? Quelle correction apporter pour que le programme affiche ce titre au-dessus du graphique ?

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

# Masse d'une balle de tennis en kilogramme et de g Newton par kilogramme
m=0.058
g=9.81

# Définition des listes
t=[0.04,0.08,0.12,0.16,0.2,0.24,0.28,0.32,0.36,0.4,0.44,0.48,0.52,0.56,0.6,0.64,0.68,0.72,0.76,0.8,0.84,0.88]     
x =[0.264,0.335,0.411,0.487,0.559,0.631,0.698,0.770,0.838,0.909,0.977,1.053,1.116,1.179,1.247,1.314,1.382,1.449,1.517,1.585,1.652,1.715]     
y=[0.538,0.702,0.846,0.972,1.078,1.17,1.242,1.301,1.339,1.364,1.377,1.373,1.347,1.314,1.263,1.196,1.116,1.017,0.901,0.774,0.631,0.471]
v=[4.727,4.267,3.870,3.436,3.058,2.693,2.387,2.121,1.912,1.804,1.797,1.780,1.746,1.946,2.242,2.500,2.783,3.174,3.491,3.771,4.131,4.435]
Ec=[]
Epp=[]
Em=[]

# Détermination du nombre total de mesures
N=len(t)                 # len(t) donne longueur de la liste t (nombre de valeurs)

# On affiche la valeur minimale de la vitesse
print('la valeur minimale de la vitesse est : ',max(v),' m/s')      # max(v) donne la valeur minimale de la liste v

# Calcul des énergies        # Dans la boucle, les instructions indentées (décalées vers la droite) sont répétées
for i in range(0,N):         # pour i qui prend les valeurs 0, puis 1, puis... jusqu'à N-1
    Ec.append(i)             # Ec.append(i) ajoute la valeur i à la liste Ec
    Epp.append(-i)           # Epp.append(-i) ajoute la valeur -i à la liste Epp
    Em.append(Ec[i]-Epp[i])  # Em.append(Ec[i]-Epp[i]) fait la différence entre les valeurs numérotées i des listes Ec et Epp

# Présentation des graphiques
plt.figure('Figure 1')
plt.plot(x,y,'ro')
plt.xlabel('x (en m)')
plt.ylabel('y en(m)')
plt.figure('Figure 2')
plt.plot(t,Ec,'r+',t,Epp,'b+',t,Em,'g*')
plt.xlabel('t (en s)')
plt.ylabel('E (en J)')
plt.legend(['?','?','?'])
plt.show()

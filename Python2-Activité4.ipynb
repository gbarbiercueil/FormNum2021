# %% [markdown]
# # <div class="alert alert-info" role="alert"> <center> Python 2 : Activité n°4
# ## <center> Titrage conductimétrique et incertitude-type composée
#
# On a réalisé le titrage de V<sub>a</sub> = 20,00 mL (incertitude-type u(V<sub>a</sub>) = 0,03 mL) d'une solution aqueuse d'acide sulfamique NH<sub>2</sub>SO<sub>3</sub>H par une solution de soude de concentration C<sub>b</sub> = 0,100 mol.L<sup>-1</sup> (incertitude-type u(C<sub>b</sub>) = 0,005 mol.L<sup>-1</sup>). On mesure un volume équivalent V<sub>eq</sub> = 10,40 mL (incertitude type u(V<sub>eq</sub>) = 0,05 mL). L'équation chimique du titrage est :      NH<sub>2</sub>SO<sub>3</sub>H + HO<sup>-</sup> ----> NH<sub>2</sub>SO<sub>3</sub><sup>-</sup> + H<sub>2</sub>O
# La valeur de référence pour la concentration est C<sub>a_ref</sub> = 0,0515 mol.L<sup>-1</sup> (1,00 g pour 200 mL)
#
# Vous devez écrire un programme qui :
#
# - calcule la concentration inconnue C<sub>a</sub> ;
# - réalise 100 000 tirages de (V<sub>a</sub>,C<sub>b</sub>,V<sub>eq</sub>) qui tiennent compte de leur incertitude-type et calcule les 100 000 résultats obtenus pour C<sub>a</sub> ;
# - trace l'histogramme des 100 000 résultats de C<sub>a</sub> ;
# - calcule l'écart-type expérimental s<sub>n-1</sub> de ces 100 000 mesures ;
# - calcule l'incertitude-type composée et verifier qu'elle est cohérente avec l'écart-type expérimental ;
# - calcule la qualité de la mesure,
# - indique si la mesure est conforme ou non à la valaur de référence
#
# On donne: ![image.png](attachment:image.png)
#
# Quand vous avez terminé, vous pouvez passer à une autre activité...

# %%
# Taper votre code ici...
